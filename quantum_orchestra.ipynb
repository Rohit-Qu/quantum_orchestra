# %%
from qiskit import QuantumCircuit, execute
from qiskit import Aer
from qiskit.visualization import plot_histogram
from qiskit import IBMQ
import qiskit.tools.jupyter
# %qiskit_job_watcher
from IPython.display import Audio
import wave
import numpy as np
#start for the project
# Out:
# Accordion(children=(VBox(layout=Layout(max_width='710px', min_width='710px')),), layout=Layout(max_height='500…

# %%
#minimum user input will just be for them to fill out the create quantum circuit function inthe backend
n = 1  #insert number of qubits
def CreateQuantumCircuit(n):
    cct = QuantumCircuit(n,1)
    cct.h(0)
    return cct

# %%
cct = CreateQuantumCircuit(n)
cct.draw(output="mpl")

# %%
def Measurement(cct):
    backend = Aer.get_backend('statevector_simulator')
    sv = execute(cct, backend).result().get_statevector()
    return sv

# %%
sv = Measurement(cct)
print(sv)
from qiskit.visualization import plot_state_city
plot_state_city(sv)
# Out:
# [0.70710678+0.j 0.70710678+0.j]

# %%
def MusicalTransformation():
    note = 'a';
    return note

# %%
tune_array = [] #collect notes
for i in range(n):
  note = MusicalTransformation()
  tune_array.append(note)
print(tune_array)
# Out:
# ['a']

# %%
def PlayPianoTune(tune_array): 
    for i in range(n):
        if tune_array[i-1] == 'a':
            sound_file = "http://mrclan.com/fastdl/tfc/sound/piano/a.wav"
            Audio(sound_file, autoplay=True)
        if tune_array[i-1] == 'b':
            sound_file = "http://mrclan.com/fastdl/tfc/sound/piano/b.wav"
            Audio(sound_file, autoplay=True)
        if tune_array[i-1] == 'c':
            sound_file = "http://mrclan.com/fastdl/tfc/sound/piano/c.wav"
            Audio(sound_file, autoplay=True)
        if tune_array[i-1] == 'd':
            sound_file = "http://mrclan.com/fastdl/tfc/sound/piano/d.wav"
            Audio(sound_file, autoplay=True)
        if tune_array[i-1] == 'e':
            sound_file = "http://mrclan.com/fastdl/tfc/sound/piano/e.wav"
            Audio(sound_file, autoplay=True)
    #return file

# %%
#sound_file = CreatePianoTune()
PlayPianoTune(tune_array)
#sound_file = "http://mrclan.com/fastdl/tfc/sound/piano/a.wav"
#Audio(sound_file, autoplay=True)

# %%
sound_file = "http://mrclan.com/fastdl/tfc/sound/xmix.wav"
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
